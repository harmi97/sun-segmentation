# %% [markdown]
# # Segmentation of coronal holes with Convolution Neural Network

# %%
import sys, os
sys.path.append('../src')

# %%
import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
import albumentations

from model_unet import unet
from metrics import dice_np, iou_np, dice, iou
from utils import plot_imgs, plot_metrics

from ImageDataAugmentor.image_data_augmentor import *

# %%
# Create lists with path to each file
imgs = glob.glob("../data/193/193_abp_1024/imgs/*.png")
masks = glob.glob("../data/193/193_abp_1024/masks/*.png")

print(f"Imgs number = {len(imgs)}\nMasks number = {len(masks)}")
# Out:
# Imgs number = 7872
# Masks number = 7872

# %%
# Load data and convert imgs to np.array
IMG_SIZE = 256  # resize imgs to 256x256
imgs_list = []
masks_list = []
for image, mask in zip(imgs, masks):
    imgs_list.append(np.array(Image.open(image).convert("L").resize((IMG_SIZE, IMG_SIZE))))
    masks_list.append(np.array(Image.open(mask).convert("L").resize((IMG_SIZE, IMG_SIZE))))

# %%
# Normalization from (0; 255) to (0; 1)
x = np.asarray(imgs_list, dtype=np.float32)/255
y = np.asarray(masks_list, dtype=np.float32)/255

# Reshape to (n_imgs, height, width, channels)
x = x.reshape(x.shape[0], x.shape[1], x.shape[2], 1)
y = y.reshape(y.shape[0], y.shape[1], y.shape[2], 1)

# Split data to Train set (90%) and Validation set (10%)
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.1, random_state=None, shuffle=True)

# %%
# Define which image augmentations we want to use
AUGMENTATIONS = albumentations.Compose([
    albumentations.HorizontalFlip(p=.5),
    albumentations.VerticalFlip(p=.5),
    albumentations.Rotate((-45, 45), p=.5, border_mode=cv2.BORDER_REPLICATE),
    # Make imgs little brigther
    albumentations.RandomGamma((100, 150), p=.5),
    albumentations.RandomBrightnessContrast((.0, .2), (.0, .4), p=.5)
])

# Set batch size
BATCH_SIZE = 20

# Generator for images
img_data_gen = ImageDataAugmentor(augment=AUGMENTATIONS, augment_seed=42)
img_gen = img_data_gen.flow(x_train, batch_size=BATCH_SIZE, shuffle=True, seed=42)

# Generator for masks
mask_data_gen = ImageDataAugmentor(augment=AUGMENTATIONS, augment_seed=42, augment_mode='mask')
mask_gen = mask_data_gen.flow(y_train, batch_size=BATCH_SIZE, shuffle=True, seed=42)

# Train set with augmented data
train_gen = zip(img_gen, mask_gen)

# %%
# Plot augmented imgs sample
x_sample, y_sample = next(train_gen)
plot_imgs(imgs=x_sample, masks=y_sample, n_imgs=5).show()

# %%
# Check if input shape is correct
input_shape = x_train[0].shape
print(f"Input shape: {input_shape}\nTrain shape: {x_train.shape}  Val shape: {x_val.shape}")
# Out:
# Input shape: (256, 256, 1)
# Train shape: (7084, 256, 256, 1)  Val shape: (788, 256, 256, 1)

# %%
MODEL_NAME = "unet_ch_segmentation"  # Specify model name
model_filename = f"../results/models/{MODEL_NAME}.h5"  # Specify path where to save model

# Create model with specific parameteres
model = unet(
    input_shape,
    filters=32,  # Doubles within each layer
    layers=4,
    batch_norm=True,
    drop_prob=0.5)

# Callback that saves only best weights
callback_checkpoint = ModelCheckpoint(
    model_filename,
    verbose=1,
    monitor="val_loss",
    save_best_only=True)

# Compile model
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",  # Loss function for binary classification
    metrics=[iou, dice]  # Metrics that we monitor during training
)

# %%
# Save model as json
model_json = model.to_json()
model_json_filename = model_filename.replace("h5", "json")
with open(model_json_filename, "w") as json_file:
    json_file.write(model_json)

# %%
EPOCHS = 100  # Set number of epochs
STEPS = x_train.shape[0] // BATCH_SIZE  # Set steps parameters acording to size of training set and size of batch

# Train model
history = model.fit(
    train_gen,
    steps_per_epoch=STEPS,
    epochs=EPOCHS,
    validation_data=(x_val, y_val),
    callbacks=[callback_checkpoint],
    verbose=2
)
# Out:
# Epoch 00001: val_loss improved from inf to 0.10853, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 256s - loss: 0.1395 - iou: 0.1529 - dice: 0.2565 - val_loss: 0.1085 - val_iou: 0.0103 - val_dice: 0.0204
#
# Epoch 00002: val_loss improved from 0.10853 to 0.04649, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 252s - loss: 0.0368 - iou: 0.3700 - dice: 0.5359 - val_loss: 0.0465 - val_iou: 0.4589 - val_dice: 0.6283
#
# Epoch 00003: val_loss improved from 0.04649 to 0.02423, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0275 - iou: 0.4718 - dice: 0.6396 - val_loss: 0.0242 - val_iou: 0.5472 - val_dice: 0.7063
#
# Epoch 00004: val_loss improved from 0.02423 to 0.02128, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0246 - iou: 0.5138 - dice: 0.6771 - val_loss: 0.0213 - val_iou: 0.5657 - val_dice: 0.7215
#
# Epoch 00008: val_loss improved from 0.02128 to 0.01888, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0212 - iou: 0.5747 - dice: 0.7284 - val_loss: 0.0189 - val_iou: 0.6151 - val_dice: 0.7605
#
# Epoch 00016: val_loss improved from 0.01888 to 0.01851, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0197 - iou: 0.5986 - dice: 0.7474 - val_loss: 0.0185 - val_iou: 0.6315 - val_dice: 0.7729
#
# Epoch 00018: val_loss improved from 0.01851 to 0.01767, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0195 - iou: 0.6032 - dice: 0.7511 - val_loss: 0.0177 - val_iou: 0.6607 - val_dice: 0.7945
#
# Epoch 00024: val_loss improved from 0.01697 to 0.01689, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0187 - iou: 0.6159 - dice: 0.7610 - val_loss: 0.0169 - val_iou: 0.6584 - val_dice: 0.7929
#
# Epoch 00040: val_loss improved from 0.01689 to 0.01686, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 250s - loss: 0.0176 - iou: 0.6359 - dice: 0.7762 - val_loss: 0.0169 - val_iou: 0.6538 - val_dice: 0.7896
#
# Epoch 00042: val_loss improved from 0.01686 to 0.01613, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 250s - loss: 0.0175 - iou: 0.6341 - dice: 0.7748 - val_loss: 0.0161 - val_iou: 0.6689 - val_dice: 0.8005
#
# Epoch 00052: val_loss improved from 0.01613 to 0.01604, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0167 - iou: 0.6473 - dice: 0.7848 - val_loss: 0.0160 - val_iou: 0.6675 - val_dice: 0.7995
#
# Epoch 00053: val_loss improved from 0.01604 to 0.01591, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0170 - iou: 0.6401 - dice: 0.7794 - val_loss: 0.0159 - val_iou: 0.6752 - val_dice: 0.8050
#
# Epoch 00070: val_loss improved from 0.01591 to 0.01576, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0163 - iou: 0.6519 - dice: 0.7882 - val_loss: 0.0158 - val_iou: 0.6707 - val_dice: 0.8018
#
# Epoch 00071: val_loss improved from 0.01576 to 0.01571, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0166 - iou: 0.6505 - dice: 0.7870 - val_loss: 0.0157 - val_iou: 0.6877 - val_dice: 0.8138
#
# Epoch 00092: val_loss improved from 0.01557 to 0.01530, saving model to ../results/models\unet_ch_segmentation.h5
# 354/354 - 251s - loss: 0.0158 - iou: 0.6633 - dice: 0.7965 - val_loss: 0.0153 - val_iou: 0.6578 - val_dice: 0.7924

# %%
model.load_weights(model_filename)  # To use best model not latest model we need to load weights from .h5 file
y_pred = model.predict(x_val)  # Predict new masks for validation set

# %%
# Plot training history and predicted imgs
plot_metrics(history).show()
plot_imgs(imgs=x_val, masks=y_val, predictions=y_pred, n_imgs=2).show()

# %%
# Results
y_pred_bin = np.where(y_pred > 0.5, 1, 0)  # Threshold predicted values

dice = np.round(dice_np(y_val, y_pred), 4)
iou_val = np.round(iou_np(y_val, y_pred), 4)

dice_tresh = np.round(dice_np(y_val, y_pred_bin), 4)
iou_val_tresh = np.round(iou_np(y_val, y_pred_bin), 4)

print(f"Validation:\nDice: {dice} Dice_tresh: {dice_tresh}\n IoU: {iou_val} IoU_tresh: {iou_val_tresh}\n")
# Out:
# Validation:
# Dice: 0.7935 Dice_tresh: 0.8695
#  IoU: 0.6577 IoU_tresh: 0.7691

# %% [markdown]
# ## Test set

# %%
# Create lists with path to each file
imgs_test = glob.glob("../data/193/193(2017)_1024/imgs(region)/*.png")
masks_test = glob.glob("../data/193/193(2017)_1024/masks(region)/*.png")

print(f"Imgs number = {len(imgs_test)}\nMasks number = {len(masks_test)}")
# Out:
# Imgs number = 353
# Masks number = 353

# %%
# Load data and convert imgs to np.array
IMG_SIZE = 256  # resize imgs to 256x256
imgs_list = []
masks_list = []
for image, mask in zip(imgs_test, masks_test):
    imgs_list.append(np.array(Image.open(image).convert("L").resize((IMG_SIZE, IMG_SIZE))))
    masks_list.append(np.array(Image.open(mask).convert("L").resize((IMG_SIZE, IMG_SIZE))))

# Normalization from (0; 255) to (0; 1)
x_test = np.asarray(imgs_list, dtype=np.float32)/255
y_test = np.asarray(masks_list, dtype=np.float32)/255

# Reshape to (n_imgs, height, width, channels)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)
y_test = y_test.reshape(y_test.shape[0], y_test.shape[1], y_test.shape[2], 1)

# %%
y_pred = model.predict(x_test)  # Predict new masks for validation set
plot_imgs(imgs=x_test, masks=y_test, predictions=y_pred, n_imgs=5).show()

# %%
# Results
y_pred_bin = np.where(y_pred > 0.5, 1, 0)  # Binarize predicted values

dice = np.round(dice_np(y_test, y_pred), 4)
iou_test = np.round(iou_np(y_test, y_pred), 4)

dice_tresh = np.round(dice_np(y_test, y_pred_bin), 4)
iou_test_tresh = np.round(iou_np(y_test, y_pred_bin), 4)

print(f"Test:\nDice: {dice} Dice_tresh: {dice_tresh}\n IoU: {iou_test} IoU_tresh: {iou_test_tresh}\n")
# Out:
# Test:
# Dice: 0.8003 Dice_tresh: 0.8668
#  IoU: 0.6671 IoU_tresh: 0.7649
